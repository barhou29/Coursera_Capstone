# %%
import requests 
import pandas as pd 
import numpy as np 
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
from IPython.display import Image 
from IPython.core.display import HTML 
from pandas.io.json import json_normalize
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
ClIENT_ID = 'NIFMB2XU3U2H3LWRBPZ1TOOCAIR2GVRDHRO5ZI4CTNFBQJXU'
ClIENT_SECRET = 'GU34LBGBFOWO0GHQIDSAKGM3TUQVWZFPDE52QQZVDOTQOTJI' 
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: NIFMB2XU3U2H3LWRBPZ1TOOCAIR2GVRDHRO5ZI4CTNFBQJXU
# Foursquare_Secret:GU34LBGBFOWO0GHQIDSAKGM3TUQVWZFPDE52QQZVDOTQOTJI

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %%
search_query = 'Hotel'
radius = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NIFMB2XU3U2H3LWRBPZ1TOOCAIR2GVRDHRO5ZI4CTNFBQJXU&client_secret=GU34LBGBFOWO0GHQIDSAKGM3TUQVWZFPDE52QQZVDOTQOTJI&ll=43.6534817,-79.3839347&v=20180604&query=Hotel&radius=500&limit=30'

# %%
results = requests.get(url).json()

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id        location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3   123 Queen Street West          CA       Toronto
# 1  51d212c3498ebf27dc469bc9  33 Gerrard Street West          CA       Toronto
# 2  4ae61cf6f964a520caa421e3         200 Victoria St          CA       Toronto
# 3  4b68aed1f964a520de862be3          194 Queen St W          CA       Toronto
# 4  51e48697498eded9073c6c17  33 Gerrard Street West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                324
# 1           Canada          at Yonge St                562
# 2           Canada         at Shuter St                410
# 3           Canada  Queen & St. Patrick                499
# 4           Canada                  NaN                522
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [33 Gerrard Street West (at Yonge St), Toronto...
# 2  [200 Victoria St (at Shuter St), Toronto ON, C...
# 3  [194 Queen St W (Queen & St. Patrick), Toronto...
# 4       [33 Gerrard Street West, Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...     43.650594
# 1  [{'label': 'display', 'lat': 43.65849759157591...     43.658498
# 2  [{'label': 'display', 'lat': 43.65449797039222...     43.654498
# 3  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 4  [{'label': 'display', 'lat': 43.65809435580944...     43.658094
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384530                   NaN             M5H 2M9             ON
# 1    -79.383097                   NaN             M5G 1Z4             ON
# 2    -79.379035                   NaN                 NaN             ON
# 3    -79.388577                   NaN             M5V 1Z1             ON
# 4    -79.382711                   NaN                 NaN             ON
#
#                              name    referralId venuePage.id
# 0   Sheraton Centre Toronto Hotel  v-1591322281          NaN
# 1                   Chelsea Hotel  v-1591322281          NaN
# 2            Pantages Hotel & Spa  v-1591322281          NaN
# 3  The Rex Hotel Jazz & Blues Bar  v-1591322281     62225795
# 4   Crew Room Eaton Chelsea Hotel  v-1591322281          NaN

# %%
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]


def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                              name categories                 address  cc  \
# 0   Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West  CA
# 1                   Chelsea Hotel      Hotel  33 Gerrard Street West  CA
# 2            Pantages Hotel & Spa      Hotel         200 Victoria St  CA
# 3  The Rex Hotel Jazz & Blues Bar  Jazz Club          194 Queen St W  CA
# 4   Crew Room Eaton Chelsea Hotel      Hotel  33 Gerrard Street West  CA
#
#       city country          crossStreet  distance  \
# 0  Toronto  Canada          at York St.       324
# 1  Toronto  Canada          at Yonge St       562
# 2  Toronto  Canada         at Shuter St       410
# 3  Toronto  Canada  Queen & St. Patrick       499
# 4  Toronto  Canada                  NaN       522
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [33 Gerrard Street West (at Yonge St), Toronto...
# 2  [200 Victoria St (at Shuter St), Toronto ON, C...
# 3  [194 Queen St W (Queen & St. Patrick), Toronto...
# 4       [33 Gerrard Street West, Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...  43.650594 -79.384530
# 1  [{'label': 'display', 'lat': 43.65849759157591...  43.658498 -79.383097
# 2  [{'label': 'display', 'lat': 43.65449797039222...  43.654498 -79.379035
# 3  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 4  [{'label': 'display', 'lat': 43.65809435580944...  43.658094 -79.382711
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN    M5G 1Z4    ON  51d212c3498ebf27dc469bc9
# 2          NaN        NaN    ON  4ae61cf6f964a520caa421e3
# 3          NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 4          NaN        NaN    ON  51e48697498eded9073c6c17

# %%
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 1                                    Chelsea Hotel
# 2                             Pantages Hotel & Spa
# 3                   The Rex Hotel Jazz & Blues Bar
# 4                    Crew Room Eaton Chelsea Hotel
# 5                                   VFM Test Hotel
# 6                  One King West Hotel & Residence
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 8                                  Stathcona Hotel
# 9                Sheraton Centre Hotel Club Lounge
# 10  Sheraton Centre Toronto Hotel - Grand Ballroom
# 11                                  Pentagos hotel
# 12                Shizen Spa at the Pantages Hotel
# 13                                       650 Hotel
# 14                      The Adelaide Hotel Toronto
# 15                                  St Regis Hotel
# 16                               Be SixFifty Hotel
# 17                              Pantages Hotel Gym
# 18                   Pantages Hotel Toronto Centre
# 19                   The Spa At The Adelaide Hotel
# 20                    Bond Place Hotel Parking Lot
# 21         Smoldering remains of the Empress Hotel
# 22              Henri's Bar at One King West hotel
# 23  Chelsea Hotel, Toronto Meetings & Events Venue
# 24           Suites at One King West Hotel Toronto
# 25                            DoubleTree by Hilton
# 26                           89 Chestnut Residence
# 27    Marriott Downtown at CF Toronto Eaton Centre
# 28                                  Fitness Centre
# 29                                  Fitness Centre
#
#                                   categories                        address  \
# 0                                      Hotel          123 Queen Street West
# 1                                      Hotel         33 Gerrard Street West
# 2                                      Hotel                200 Victoria St
# 3                                  Jazz Club                 194 Queen St W
# 4                                      Hotel         33 Gerrard Street West
# 5                                      Hotel                 123 Test Drive
# 6                                      Hotel                    1 King St W
# 7                                      Hotel                  8 Colborne St
# 8                                      Hotel                            NaN
# 9                                     Lounge                            NaN
# 10                                  Ballroom          123 Queen Street West
# 11  Residential Building (Apartment / Condo)                            NaN
# 12                                       Spa                200 Victoria St
# 13                                     Hotel                 650 Bay Street
# 14                                     Hotel                     325 Bay St
# 15                                     Hotel                     325 Bay St
# 16                                     Hotel                 650 Bay Street
# 17                                       Gym               200 Victoria St.
# 18  Residential Building (Apartment / Condo)            200 Victoria Street
# 19                                       Spa                     325 Bay St
# 20                        Miscellaneous Shop                Bond And Dundas
# 21                                     Hotel                   335 Yonge St
# 22                       American Restaurant                    1 King West
# 23                         Convention Center         33 Gerrard Street West
# 24                                     Hotel  1 King St W Toronto ON Canada
# 25                                     Hotel            108 Chestnut Street
# 26                    College Residence Hall                89 Chestnut St.
# 27                                     Hotel                 525 Bay Street
# 28                                       Gym                    525 Bay St.
# 29                                       Gym                Sheraton Centre
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 1   43.658498 -79.383097    M5G 1Z4    ON
# 2   43.654498 -79.379035        NaN    ON
# 3   43.650505 -79.388577    M5V 1Z1    ON
# 4   43.658094 -79.382711        NaN    ON
# 5   43.658434 -79.387894    M2M 2M2    ON
# 6   43.649139 -79.377876    M5H 1A1    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 8   43.654947 -79.386359        NaN    ON
# 9   43.651063 -79.384527    M5H 2M9    ON
# 10  43.651200 -79.384520        NaN    ON
# 11  43.653976 -79.379875        NaN    ON
# 12  43.655198 -79.379913        NaN    ON
# 13  43.657046 -79.384411        NaN    ON
# 14  43.649831 -79.380164    M5H 4G3    ON
# 15  43.649770 -79.380701    M5H 4G3    ON
# 16  43.657120 -79.384560        NaN    ON
# 17  43.654464 -79.379036    M5B 1V8    ON
# 18  43.655205 -79.379182    M5B 1V8    ON
# 19  43.649725 -79.380346    M5H 4G5    ON
# 20  43.656224 -79.378830        NaN   NaN
# 21  43.657956 -79.381698        NaN    ON
# 22  43.648945 -79.378028        NaN    ON
# 23  43.658446 -79.382985    M5G 1Z4    ON
# 24  43.649077 -79.378468        NaN    ON
# 25  43.654608 -79.385942    M5G 1R3    ON
# 26  43.654160 -79.385291    M5G 1R1    ON
# 27  43.654728 -79.382422    M5G 2L2    ON
# 28  43.654690 -79.381739    M5G 2L2    ON
# 29  43.650985 -79.384002    M5H 2M9    ON

# %%
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 1                                    Chelsea Hotel
# 3                   The Rex Hotel Jazz & Blues Bar
# 5                                   VFM Test Hotel
# 6                  One King West Hotel & Residence
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 14                      The Adelaide Hotel Toronto
# 15                                  St Regis Hotel
# 17                              Pantages Hotel Gym
# 18                   Pantages Hotel Toronto Centre
# 19                   The Spa At The Adelaide Hotel
# 23  Chelsea Hotel, Toronto Meetings & Events Venue
# 25                            DoubleTree by Hilton
# 26                           89 Chestnut Residence
# 27    Marriott Downtown at CF Toronto Eaton Centre
# 28                                  Fitness Centre
# 29                                  Fitness Centre
#
#                                   categories                 address  \
# 0                                      Hotel   123 Queen Street West
# 1                                      Hotel  33 Gerrard Street West
# 3                                  Jazz Club          194 Queen St W
# 5                                      Hotel          123 Test Drive
# 6                                      Hotel             1 King St W
# 7                                      Hotel           8 Colborne St
# 14                                     Hotel              325 Bay St
# 15                                     Hotel              325 Bay St
# 17                                       Gym        200 Victoria St.
# 18  Residential Building (Apartment / Condo)     200 Victoria Street
# 19                                       Spa              325 Bay St
# 23                         Convention Center  33 Gerrard Street West
# 25                                     Hotel     108 Chestnut Street
# 26                    College Residence Hall         89 Chestnut St.
# 27                                     Hotel          525 Bay Street
# 28                                       Gym             525 Bay St.
# 29                                       Gym         Sheraton Centre
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 1   43.658498 -79.383097    M5G 1Z4    ON
# 3   43.650505 -79.388577    M5V 1Z1    ON
# 5   43.658434 -79.387894    M2M 2M2    ON
# 6   43.649139 -79.377876    M5H 1A1    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 14  43.649831 -79.380164    M5H 4G3    ON
# 15  43.649770 -79.380701    M5H 4G3    ON
# 17  43.654464 -79.379036    M5B 1V8    ON
# 18  43.655205 -79.379182    M5B 1V8    ON
# 19  43.649725 -79.380346    M5H 4G5    ON
# 23  43.658446 -79.382985    M5G 1Z4    ON
# 25  43.654608 -79.385942    M5G 1R3    ON
# 26  43.654160 -79.385291    M5G 1R1    ON
# 27  43.654728 -79.382422    M5G 2L2    ON
# 28  43.654690 -79.381739    M5G 2L2    ON
# 29  43.650985 -79.384002    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 1                                  Chelsea Hotel      Hotel
# 5                                 VFM Test Hotel      Hotel
# 6                One King West Hotel & Residence      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 14                    The Adelaide Hotel Toronto      Hotel
# 15                                St Regis Hotel      Hotel
# 25                          DoubleTree by Hilton      Hotel
# 27  Marriott Downtown at CF Toronto Eaton Centre      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 5           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 6              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 14              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 15              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 25     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 27          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 1                                  Chelsea Hotel      Hotel
# 5                                 VFM Test Hotel      Hotel
# 6                One King West Hotel & Residence      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 14                    The Adelaide Hotel Toronto      Hotel
# 15                                St Regis Hotel      Hotel
# 25                          DoubleTree by Hilton      Hotel
# 27  Marriott Downtown at CF Toronto Eaton Centre      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 5           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 6              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 14              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 15              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 25     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 27          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                             name categories                address        lat  \
# 0  Sheraton Centre Toronto Hotel      Hotel  123 Queen Street West  43.650594
#
#         lng postalCode state
# 0 -79.38453    M5H 2M9    ON

# %%
search_query = 'Park'
radius = 10000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NIFMB2XU3U2H3LWRBPZ1TOOCAIR2GVRDHRO5ZI4CTNFBQJXU&client_secret=GU34LBGBFOWO0GHQIDSAKGM3TUQVWZFPDE52QQZVDOTQOTJI&ll=43.6534817,-79.3839347&v=20180604&query=Park&radius=10000&limit=30'

# %%
presults = requests.get(url).json()

# %%
venues = presults['response']['venues']

park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...    False
#
#                          id        location.address location.cc location.city  \
# 0  4b170e47f964a5208cc123e3      691 University Ave          CA       Toronto
# 1  4b54deadf964a520a3d027e3                     NaN          CA       Toronto
# 2  4bb79860cf2fc9b616779e02  35 Wellington St. East          CA       Toronto
# 3  4b9d206bf964a520e69136e3         University Ave.          CA       Toronto
# 4  4b9177e4f964a520d2be33e3                     NaN          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at College St                887
# 1           Canada                  NaN                663
# 2           Canada                  NaN                929
# 3           Canada    at Wellesley Ave.               1340
# 4           Canada                  NaN                389
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2       [35 Wellington St. East, Toronto ON, Canada]
# 3  [University Ave. (at Wellesley Ave.), Toronto ...
# 4                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.64804835388851...     43.648048
# 3  [{'label': 'display', 'lat': 43.66394609897775...     43.663946
# 4  [{'label': 'display', 'lat': 43.650735, 'lng':...     43.650735
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.375172                 NaN             ON
# 3    -79.392180             M5R 2E8             ON
# 4    -79.386921                 NaN             ON
#
#                                  name    referralId venuePage.id
# 0         Queen's Park Subway Station  v-1591322282          NaN
# 1                         Grange Park  v-1591322282          NaN
# 2                         Berczy Park  v-1591322282          NaN
# 3                        Queen's Park  v-1591322282          NaN
# 4  TTC Streetcar #403 - Victoria park  v-1591322282          NaN

# %%
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                  name          categories  \
# 0         Queen's Park Subway Station       Metro Station
# 1                         Grange Park                Park
# 2                         Berczy Park                Park
# 3                        Queen's Park                Park
# 4  TTC Streetcar #403 - Victoria park  Light Rail Station
#
#                   address  cc     city country        crossStreet  distance  \
# 0      691 University Ave  CA  Toronto  Canada      at College St       887
# 1                     NaN  CA  Toronto  Canada                NaN       663
# 2  35 Wellington St. East  CA  Toronto  Canada                NaN       929
# 3         University Ave.  CA  Toronto  Canada  at Wellesley Ave.      1340
# 4                     NaN  CA  Toronto  Canada                NaN       389
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2       [35 Wellington St. East, Toronto ON, Canada]
# 3  [University Ave. (at Wellesley Ave.), Toronto ...
# 4                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.64804835388851...  43.648048 -79.375172
# 3  [{'label': 'display', 'lat': 43.66394609897775...  43.663946 -79.392180
# 4  [{'label': 'display', 'lat': 43.650735, 'lng':...  43.650735 -79.386921
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2        NaN    ON  4bb79860cf2fc9b616779e02
# 3    M5R 2E8    ON  4b9d206bf964a520e69136e3
# 4        NaN    ON  4b9177e4f964a520d2be33e3

# %%
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                   name  \
# 0          Queen's Park Subway Station
# 1                          Grange Park
# 2                          Berczy Park
# 3                         Queen's Park
# 4   TTC Streetcar #403 - Victoria park
# 5    St. Andrews Playground / Dog Park
# 6                        One Park Lane
# 7               Physiomed College Park
# 8        Crunch Fitness - College Park
# 9                 Clarence Square Park
# 10              Trinity Bellwoods Park
# 11    Residences at College Park North
# 12    Toothworks - College Park Dental
# 13                 Riverdale Park West
# 14                 Riverdale Park East
# 15                            HTO Park
# 16                Bellevue Square Park
# 17             Moss Park Tennis Courts
# 18              Parliament Square Park
# 19                 Tommy Thompson Park
# 20             St Lawrence on the Park
# 21        Orphan's Greenspace Dog Park
# 22                     Winchester Park
# 23                     Coronation Park
# 24                         Regent Park
# 25                         Regent Park
# 26                           High Park
# 27                        Stanley Park
# 28                   Barbara Hall Park
# 29        Regent Park Community Centre
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park        35 Wellington St. East
# 3                                       Park               University Ave.
# 4                         Light Rail Station                           NaN
# 5                                       Park      450 Adelaide Street West
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                             Medical Center                  382 Yonge St
# 8                       Gym / Fitness Center              382 Yonge Street
# 9                                       Park                   Spadina Ave
# 10                                      Park            1053 Dundas St. W.
# 11  Residential Building (Apartment / Condo)                   763 Bay St.
# 12                          Dentist's Office        444 Yonge St, Unit M16
# 13                                      Park               500 Gerrard St.
# 14                                      Park             550 Broadview Ave
# 15                                      Park                  Queen's Quay
# 16                                      Park  btwn Bellevue & Augusta Ave.
# 17                              Tennis Court                     Moss Park
# 18                                      Park          44 Parliament Street
# 19                                      Park                     Leslie St
# 20                                  Building               65 Scadding Ave
# 21                                   Dog Run                  51 Power St.
# 22                                Playground            530 Ontario Street
# 23                                      Park        711 Lake Shore Blvd. W
# 24                              Neighborhood                           NaN
# 25                                      Park              620 Dundas St E.
# 26                                      Park              1873 Bloor St. W
# 27                                      Park              King Street West
# 28                                      Park             519 Church Street
# 29                          Community Center               465 Dundas St E
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.648048 -79.375172        NaN    ON
# 3   43.663946 -79.392180    M5R 2E8    ON
# 4   43.650735 -79.386921        NaN    ON
# 5   43.647388 -79.398752        NaN    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.659240 -79.382860    M5B 1S8    ON
# 8   43.659263 -79.382632    M5G 1S8    ON
# 9   43.644222 -79.394230        NaN    ON
# 10  43.647072 -79.413756    M5H 2N2    ON
# 11  43.659822 -79.385159    M5G 2R3    ON
# 12  43.660009 -79.383905        NaN    ON
# 13  43.666048 -79.360941    M5A 2H3    ON
# 14  43.669951 -79.355493    M4K 2P1    ON
# 15  43.637949 -79.387820        NaN    ON
# 16  43.653610 -79.402199    M5T 2N4    ON
# 17  43.655337 -79.371923        NaN    ON
# 18  43.650264 -79.362195        NaN    ON
# 19  43.634180 -79.323671        NaN    ON
# 20  43.648963 -79.364868        NaN    ON
# 21  43.654654 -79.362501        NaN    ON
# 22  43.666231 -79.371631        NaN    ON
# 23  43.634553 -79.405403    M5V 3T7    ON
# 24  43.660009 -79.364191        NaN    ON
# 25  43.660383 -79.361810        NaN    ON
# 26  43.646479 -79.463425    M6R 2Z3    ON
# 27  43.642395 -79.409330        NaN    ON
# 28  43.666728 -79.381084        NaN    ON
# 29  43.659512 -79.363048    M5A 2B2    ON

# %%
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                 name  \
# 0        Queen's Park Subway Station
# 3                       Queen's Park
# 6                      One Park Lane
# 7             Physiomed College Park
# 8      Crunch Fitness - College Park
# 10            Trinity Bellwoods Park
# 11  Residences at College Park North
# 13               Riverdale Park West
# 14               Riverdale Park East
# 16              Bellevue Square Park
# 23                   Coronation Park
# 26                         High Park
# 29      Regent Park Community Centre
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 3                                       Park               University Ave.
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                             Medical Center                  382 Yonge St
# 8                       Gym / Fitness Center              382 Yonge Street
# 10                                      Park            1053 Dundas St. W.
# 11  Residential Building (Apartment / Condo)                   763 Bay St.
# 13                                      Park               500 Gerrard St.
# 14                                      Park             550 Broadview Ave
# 16                                      Park  btwn Bellevue & Augusta Ave.
# 23                                      Park        711 Lake Shore Blvd. W
# 26                                      Park              1873 Bloor St. W
# 29                          Community Center               465 Dundas St E
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 3   43.663946 -79.392180    M5R 2E8    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.659240 -79.382860    M5B 1S8    ON
# 8   43.659263 -79.382632    M5G 1S8    ON
# 10  43.647072 -79.413756    M5H 2N2    ON
# 11  43.659822 -79.385159    M5G 2R3    ON
# 13  43.666048 -79.360941    M5A 2H3    ON
# 14  43.669951 -79.355493    M4K 2P1    ON
# 16  43.653610 -79.402199    M5T 2N4    ON
# 23  43.634553 -79.405403    M5V 3T7    ON
# 26  43.646479 -79.463425    M6R 2Z3    ON
# 29  43.659512 -79.363048    M5A 2B2    ON

# %%
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 3             Queen's Park       Park               University Ave.
# 10  Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 13     Riverdale Park West       Park               500 Gerrard St.
# 14     Riverdale Park East       Park             550 Broadview Ave
# 16    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 23         Coronation Park       Park        711 Lake Shore Blvd. W
# 26               High Park       Park              1873 Bloor St. W
#
#           lat        lng postalCode state
# 3   43.663946 -79.392180    M5R 2E8    ON
# 10  43.647072 -79.413756    M5H 2N2    ON
# 13  43.666048 -79.360941    M5A 2H3    ON
# 14  43.669951 -79.355493    M4K 2P1    ON
# 16  43.653610 -79.402199    M5T 2N4    ON
# 23  43.634553 -79.405403    M5V 3T7    ON
# 26  43.646479 -79.463425    M6R 2Z3    ON

# %%
search_query = 'Restaurant'
radius = 10000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NIFMB2XU3U2H3LWRBPZ1TOOCAIR2GVRDHRO5ZI4CTNFBQJXU&client_secret=GU34LBGBFOWO0GHQIDSAKGM3TUQVWZFPDE52QQZVDOTQOTJI&ll=43.6534817,-79.3839347&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
Rresults = requests.get(url).json()

# %%
venues = Rresults['response']['venues']

Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ad4c05cf964a52006f620e3  37 King Street East          CA       Toronto
# 2  5750b013498e755287c6de97   988 Baldwin Street          CA       Toronto
# 3  4b074bb1f964a52077fb22e3     353 Spadina Ave.          CA       Toronto
# 4  4aef8854f964a5201cd921e3       287 King St. W          CA       Toronto
#
#   location.country              location.crossStreet  location.distance  \
# 0           Canada                               NaN                224
# 1           Canada  at Le Meridien King Edward Hotel                763
# 2           Canada                               NaN                839
# 3           Canada                               NaN               1222
# 4           Canada                       at John St.                906
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [37 King Street East (at Le Meridien King Edwa...
# 2           [988 Baldwin Street, Toronto ON, Canada]
# 3     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
# 4  [287 King St. W (at John St.), Toronto ON M5V ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.64929834396347...     43.649298
# 2  [{'label': 'display', 'lat': 43.655874, 'lng':...     43.655874
# 3  [{'label': 'display', 'lat': 43.65533674412141...     43.655337
# 4  [{'label': 'display', 'lat': 43.64646252150344...     43.646463
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.385931                   NaN             M5G 1R3             ON
# 1    -79.376431                   NaN             M5C 1E9             ON
# 2    -79.393826                   NaN                 NaN             ON
# 3    -79.398897                   NaN             M5T 2G3             ON
# 4    -79.389644                   NaN             M5V 1J5             ON
#
#                                  name    referralId venuePage.id
# 0     Hemispheres Restaurant & Bistro  v-1591322283          NaN
# 1               Victoria's Restaurant  v-1591322283    498556908
# 2  Some Time BBQ Grill Restaurant 碳烤屋  v-1591322283          NaN
# 3            New Sky Restaurant 小沙田食家  v-1591322283          NaN
# 4        Aroma Fine Indian Restaurant  v-1591322283          NaN

# %%
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0     Hemispheres Restaurant & Bistro  American Restaurant
# 1               Victoria's Restaurant           Restaurant
# 2  Some Time BBQ Grill Restaurant 碳烤屋  Szechuan Restaurant
# 3            New Sky Restaurant 小沙田食家   Chinese Restaurant
# 4        Aroma Fine Indian Restaurant    Indian Restaurant
#
#                address  cc     city country                       crossStreet  \
# 0  110 Chestnut Street  CA  Toronto  Canada                               NaN
# 1  37 King Street East  CA  Toronto  Canada  at Le Meridien King Edward Hotel
# 2   988 Baldwin Street  CA  Toronto  Canada                               NaN
# 3     353 Spadina Ave.  CA  Toronto  Canada                               NaN
# 4       287 King St. W  CA  Toronto  Canada                       at John St.
#
#    distance                                   formattedAddress  \
# 0       224  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1       763  [37 King Street East (at Le Meridien King Edwa...
# 2       839           [988 Baldwin Street, Toronto ON, Canada]
# 3      1222     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
# 4       906  [287 King St. W (at John St.), Toronto ON M5V ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.64929834396347...  43.649298 -79.376431
# 2  [{'label': 'display', 'lat': 43.655874, 'lng':...  43.655874 -79.393826
# 3  [{'label': 'display', 'lat': 43.65533674412141...  43.655337 -79.398897
# 4  [{'label': 'display', 'lat': 43.64646252150344...  43.646463 -79.389644
#
#   neighborhood postalCode state                        id
# 0          NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1          NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 2          NaN        NaN    ON  5750b013498e755287c6de97
# 3          NaN    M5T 2G3    ON  4b074bb1f964a52077fb22e3
# 4          NaN    M5V 1J5    ON  4aef8854f964a5201cd921e3

# %%
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                        name               categories  \
# 0           Hemispheres Restaurant & Bistro      American Restaurant
# 1                     Victoria's Restaurant               Restaurant
# 2        Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 3                  New Sky Restaurant 小沙田食家       Chinese Restaurant
# 4              Aroma Fine Indian Restaurant        Indian Restaurant
# 5                    Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 6                    Azure Restaurant & Bar               Restaurant
# 7                   Victor Restaurant & Bar                      Bar
# 8            The Hot House Restaurant & Bar      American Restaurant
# 9        North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 10                        Studio Restaurant           Breakfast Spot
# 11            Green Tea Restaurant Downtown       Chinese Restaurant
# 12           Goldstone Noodle Restaurant 金石             Noodle House
# 13                  Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 14                           360 Restaurant                 Wine Bar
# 15                 Ka Chi Korean Restaurant        Korean Restaurant
# 16              Cottage Restaurant & Lounge          Thai Restaurant
# 17  Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 18                    Sightlines Restaurant      American Restaurant
# 19        Kensington Cornerstone Restaurant           Breakfast Spot
# 20       Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 21                    Restaurant | Adelaide               Restaurant
# 22             Yueh Tung Chinese Restaurant       Chinese Restaurant
# 23            Micheal's Restaurant and Deli                      Bar
# 24        El Rancho Restaurant & Night Club                Nightclub
# 25               Hendricks Restaurant & Bar               Restaurant
# 26                   Tender Trap Restaurant       Chinese Restaurant
# 27      Richtree Natural Market Restaurants               Restaurant
# 28               Matisse Restaurant And Bar               Restaurant
# 29              Woodlot Restaurant & Bakery  New American Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 2                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 3                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 4                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 5                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 6                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 7                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 8                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 9                    476 Dundas St.  43.653185 -79.396677        NaN    ON
# 10                   389 Church St.  43.661500 -79.379319        M5B    ON
# 11  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 12                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 13                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 14                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 15                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 16                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 17                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 18                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 19               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 20                 280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 21          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 22                126 Elizabeth St.  43.655281 -79.385337        NaN    ON
# 23                   566 Queen St W  43.647289 -79.403493        NaN    ON
# 24                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 25                  Yonge And Queen  43.653415 -79.379698    M5G 2H6    ON
# 26                580 Parliament St  43.667724 -79.369485    M4X 1P8    ON
# 27                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 28                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 29              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON

# %%
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                        name               categories  \
# 0           Hemispheres Restaurant & Bistro      American Restaurant
# 1                     Victoria's Restaurant               Restaurant
# 3                  New Sky Restaurant 小沙田食家       Chinese Restaurant
# 4              Aroma Fine Indian Restaurant        Indian Restaurant
# 5                    Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 6                    Azure Restaurant & Bar               Restaurant
# 7                   Victor Restaurant & Bar                      Bar
# 8            The Hot House Restaurant & Bar      American Restaurant
# 10                        Studio Restaurant           Breakfast Spot
# 11            Green Tea Restaurant Downtown       Chinese Restaurant
# 12           Goldstone Noodle Restaurant 金石             Noodle House
# 13                  Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 14                           360 Restaurant                 Wine Bar
# 15                 Ka Chi Korean Restaurant        Korean Restaurant
# 16              Cottage Restaurant & Lounge          Thai Restaurant
# 17  Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 19        Kensington Cornerstone Restaurant           Breakfast Spot
# 21                    Restaurant | Adelaide               Restaurant
# 24        El Rancho Restaurant & Night Club                Nightclub
# 25               Hendricks Restaurant & Bar               Restaurant
# 26                   Tender Trap Restaurant       Chinese Restaurant
# 27      Richtree Natural Market Restaurants               Restaurant
# 28               Matisse Restaurant And Bar               Restaurant
# 29              Woodlot Restaurant & Bakery  New American Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 3                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 4                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 5                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 6                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 7                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 8                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 10                   389 Church St.  43.661500 -79.379319        M5B    ON
# 11  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 12                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 13                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 14                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 15                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 16                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 17                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 19               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 21          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 24                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 25                  Yonge And Queen  43.653415 -79.379698    M5G 2H6    ON
# 26                580 Parliament St  43.667724 -79.369485    M4X 1P8    ON
# 27                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 28                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 29              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON

# %%
search_query = 'Cafeteria'
radius = 10000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NIFMB2XU3U2H3LWRBPZ1TOOCAIR2GVRDHRO5ZI4CTNFBQJXU&client_secret=GU34LBGBFOWO0GHQIDSAKGM3TUQVWZFPDE52QQZVDOTQOTJI&ll=43.6534817,-79.3839347&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
cresults = requests.get(url).json()

# %%
venues = cresults['response']['venues']

Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  4b57256bf964a520332828e3                                      Yonge
# 3  53bd6dfe498e6c1d3bc9333e                                        NaN
# 4  524f1c8f498e983dde61ada0                         89 Chestnut Street
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada               Dundas
# 3          CA       Toronto           Canada                  NaN
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                448  [The Hospital for Sick Children (SickKids), To...
# 1               1246  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                387               [Yonge (Dundas), Toronto ON, Canada]
# 3                505                               [Toronto ON, Canada]
# 4                584           [89 Chestnut Street, Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65603785909391...     43.656038
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...     43.648231
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.380672                 NaN             ON
# 3    -79.389443                 NaN             ON
# 4    -79.384045                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1591322283
# 1              Stay Cafeteria 慢走  v-1591322283
# 2                Sears Cafeteria  v-1591322283
# 3  Industrial Alliance Cafeteria  v-1591322283
# 4        Chestnut Tree Cafeteria  v-1591322283

# %%
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                Sears Cafeteria            Food Court
# 3  Industrial Alliance Cafeteria             Cafeteria
# 4        Chestnut Tree Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                                      Yonge  CA  Toronto  Canada
# 3                                        NaN  CA  Toronto  Canada
# 4                         89 Chestnut Street  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       448  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St      1246  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2        Dundas       387               [Yonge (Dundas), Toronto ON, Canada]
# 3           NaN       505                               [Toronto ON, Canada]
# 4           NaN       584           [89 Chestnut Street, Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.65603785909391...  43.656038 -79.380672
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...  43.648231 -79.384045
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  4b57256bf964a520332828e3
# 3        NaN    ON  53bd6dfe498e6c1d3bc9333e
# 4        NaN    ON  524f1c8f498e983dde61ada0

# %%
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                         Sears Cafeteria            Food Court
# 3           Industrial Alliance Cafeteria             Cafeteria
# 4                 Chestnut Tree Cafeteria             Cafeteria
# 5                          OCAD Cafeteria     College Cafeteria
# 6                         Dears Cafeteria          Dessert Shop
# 7                   Ryerson Hub Cafeteria     College Cafeteria
# 8                      SickKids Cafeteria            Food Court
# 9           De La Salle College Cafeteria     College Cafeteria
# 10                      Med Sci Cafeteria     College Cafeteria
# 11              Macdonald Block Cafeteria             Cafeteria
# 12                      Robarts Cafeteria     College Cafeteria
# 13                          OMP Cafeteria             Cafeteria
# 14                       Rogers Cafeteria            Food Court
# 15                      Choices Cafeteria            Food Court
# 16    Cafeteria, Lawrence Park Collegiate           High School
# 17                             Marketeria            Restaurant
# 18    Cafeteria, Lawrence Park Collegiate           Event Space
# 19                       Kasala Cafeteria    African Restaurant
# 20                                The Hub     College Cafeteria
# 21               Estonian House Cafeteria                  Café
# 22                           CC Cafeteria     College Cafeteria
# 23  George Brown College St. James Campus     Community College
# 24                          Innis College        Student Center
# 25                             Radio Cafe            Food Court
# 26     Lawrence Park Collegiate Cafeteria           High School
# 27                           L5 Cafeteria      Cuban Restaurant
# 28  6th Floor Cafeteria 12 Concorde Place                  Café
# 29                      Glendon Cafeteria     College Cafeteria
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                                       Yonge  43.656038 -79.380672
# 3                                         NaN  43.655657 -79.389443
# 4                          89 Chestnut Street  43.648231 -79.384045
# 5                              100 McCaul St.  43.652780 -79.391762
# 6                                         NaN  43.654179 -79.392555
# 7                            350 Victoria St.  43.658475 -79.377653
# 8                       555 University Avenue  43.657584 -79.375652
# 9                          131 Farnham Avenue  43.683003 -79.397815
# 10                                        NaN  43.660260 -79.392977
# 11                                        NaN  43.663212 -79.388062
# 12                         130 St. George St.  43.664864 -79.399766
# 13                           1 Mount Pleasant  43.669801 -79.379790
# 14                                        NaN  43.669904 -79.379748
# 15                         200 Bloor Street E  43.671411 -79.381849
# 16                                        NaN  43.721732 -79.409600
# 17                                30 Bond St.  43.653585 -79.378843
# 18                                        NaN  43.723286 -79.412222
# 19                                      Bloor  43.660759 -79.424018
# 20                           350 Victoria St.  43.658585 -79.380622
# 21                       958 Broadview avenue  43.681763 -79.358246
# 22                             951 Carlaw Ave  43.684631 -79.348862
# 23                          200 King St. East  43.651366 -79.370158
# 24                               2 Sussex Ave  43.665556 -79.399298
# 25                          333 Bloor st east  43.671696 -79.380617
# 26                                        NaN  43.722757 -79.413734
# 27                                        NaN  43.723019 -79.345012
# 28                          12 Concorde Place  43.721861 -79.329339
# 29                           2275 Bayview Ave  43.727383 -79.378080
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3         NaN    ON
# 4         NaN    ON
# 5         NaN    ON
# 6         NaN   NaN
# 7         NaN    ON
# 8         NaN    ON
# 9     M4V 1H7    ON
# 10        NaN    ON
# 11        NaN   NaN
# 12        NaN    ON
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN   NaN
# 17    M5B 1W8    ON
# 18        NaN   NaN
# 19        NaN   NaN
# 20    M5B 2K3    ON
# 21        NaN    ON
# 22        NaN    ON
# 23        NaN    ON
# 24    M5S 1J5    ON
# 25        NaN    ON
# 26        NaN    ON
# 27        NaN   NaN
# 28    m3c 3k7    ON
# 29        NaN    ON

# %%
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 9           De La Salle College Cafeteria  College Cafeteria
# 17                             Marketeria         Restaurant
# 20                                The Hub  College Cafeteria
# 24                          Innis College     Student Center
# 28  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 9   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 17         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 20    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 24        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 28   12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %%
search_query = 'Shopping'
radius = 1000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NIFMB2XU3U2H3LWRBPZ1TOOCAIR2GVRDHRO5ZI4CTNFBQJXU&client_secret=GU34LBGBFOWO0GHQIDSAKGM3TUQVWZFPDE52QQZVDOTQOTJI&ll=43.6534817,-79.3839347&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
sresults = requests.get(url).json()

# %%
venues = sresults['response']['venues']
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
#
#                          id    location.address location.cc location.city  \
# 0  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 1  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 2  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada    Queen Street West                424
# 1           Canada    btw York & Bay St                741
# 2           Canada  btwn Queen & Dundas                287
#
#                            location.formattedAddress  \
# 0  [176 Yonge Street (Queen Street West), Toronto...
# 1  [66 Wellington St W (btw York & Bay St), Toron...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 1  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 2                                                NaN     43.654540
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.379192                            NaN             M5C 2L7
# 1    -79.380932                            NaN             M5K 1A1
# 2    -79.380677  Downtown Toronto, Toronto, ON             M5B 2H1
#
#   location.state                                        name    referralId
# 0             ON  Saks Fifth Avenue Club - Personal Shopping  v-1591322284
# 1             ON                TD Centre Shopping Concourse  v-1591322284
# 2             ON                     CF Toronto Eaton Centre  v-1591322284

# %%
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
#
#               address  cc     city country          crossStreet  distance  \
# 0    176 Yonge Street  CA  Toronto  Canada    Queen Street West       424
# 1  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       741
# 2        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       287
#
#                                     formattedAddress  \
# 0  [176 Yonge Street (Queen Street West), Toronto...
# 1  [66 Wellington St W (btw York & Bay St), Toron...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 1  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 2                                                NaN  43.654540 -79.380677
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 1                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 2  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3

# %%
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
#
#               address        lat        lng postalCode state
# 0    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 1  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 2        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON

# %%
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 1  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
# 2       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
#
#          lng postalCode state
# 1 -79.380932    M5K 1A1    ON
# 2 -79.380677    M5B 2H1    ON

# %%
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                     name         categories  \
# 0          Sheraton Centre Toronto Hotel              Hotel
# 1                      Stay Cafeteria 慢走   Asian Restaurant
# 2          De La Salle College Cafeteria  College Cafeteria
# 3                             Marketeria         Restaurant
# 4                                The Hub  College Cafeteria
# 5                          Innis College     Student Center
# 6  6th Floor Cafeteria 12 Concorde Place               Café
# 7           TD Centre Shopping Concourse      Shopping Mall
# 8                CF Toronto Eaton Centre      Shopping Mall
#
#                  address        lat        lng postalCode state
# 0  123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1        388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 2     131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 3            30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 4       350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 5           2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 6      12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 7     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 8           220 Yonge St  43.654540 -79.380677    M5B 2H1    ON

# %%
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                        name               categories  \
# 0                              Queen's Park                     Park
# 1                    Trinity Bellwoods Park                     Park
# 2                       Riverdale Park West                     Park
# 3                       Riverdale Park East                     Park
# 4                      Bellevue Square Park                     Park
# 5                           Coronation Park                     Park
# 6                                 High Park                     Park
# 7           Hemispheres Restaurant & Bistro      American Restaurant
# 8                     Victoria's Restaurant               Restaurant
# 9                  New Sky Restaurant 小沙田食家       Chinese Restaurant
# 10             Aroma Fine Indian Restaurant        Indian Restaurant
# 11                   Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 12                   Azure Restaurant & Bar               Restaurant
# 13                  Victor Restaurant & Bar                      Bar
# 14           The Hot House Restaurant & Bar      American Restaurant
# 15                        Studio Restaurant           Breakfast Spot
# 16            Green Tea Restaurant Downtown       Chinese Restaurant
# 17           Goldstone Noodle Restaurant 金石             Noodle House
# 18                  Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 19                           360 Restaurant                 Wine Bar
# 20                 Ka Chi Korean Restaurant        Korean Restaurant
# 21              Cottage Restaurant & Lounge          Thai Restaurant
# 22  Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 23        Kensington Cornerstone Restaurant           Breakfast Spot
# 24                    Restaurant | Adelaide               Restaurant
# 25        El Rancho Restaurant & Night Club                Nightclub
# 26               Hendricks Restaurant & Bar               Restaurant
# 27                   Tender Trap Restaurant       Chinese Restaurant
# 28      Richtree Natural Market Restaurants               Restaurant
# 29               Matisse Restaurant And Bar               Restaurant
# 30              Woodlot Restaurant & Bakery  New American Restaurant
# 31                        Stay Cafeteria 慢走         Asian Restaurant
# 32            De La Salle College Cafeteria        College Cafeteria
# 33                               Marketeria               Restaurant
# 34                                  The Hub        College Cafeteria
# 35                            Innis College           Student Center
# 36    6th Floor Cafeteria 12 Concorde Place                     Café
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 2                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 3                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 4      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 5            711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 6                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 7               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 8               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 9                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 10                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 12                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 13                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 14                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 15                   389 Church St.  43.661500 -79.379319        M5B    ON
# 16  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 17                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 18                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 19                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 20                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 21                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 22                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 23               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 24          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 25                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 26                  Yonge And Queen  43.653415 -79.379698    M5G 2H6    ON
# 27                580 Parliament St  43.667724 -79.369485    M4X 1P8    ON
# 28                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 29                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 30              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 31                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 32               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 33                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 34                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 35                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 36                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %%
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)
